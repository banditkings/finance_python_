# %% [markdown]
# # Wine Quality Prediction
#
# (A workshop for introductory applied linear regression in Python as part of an internal analyst training program)

# %% [markdown]
# Demonstrate one of the canonical applications of linear regression - the wine quality prediction dataset!

# %%
# Import our data manipulation library
import pandas as pd

# Statistical modeling
import statsmodels.api as sm

# %% [markdown]
# The following code block will try to read in the CSV file if you have it downloaded, otherwise it'll download it from the internet and save it for future use.

# %%
try: 
    df = pd.read_csv("winequality-red.csv")
except:
    print("Downloading winequality-red from UCI ML repository...")
    url = "https://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-red.csv"
    df = pd.read_csv(url, delimiter=';')
    df.to_csv("winequality-red.csv", index=False)

df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %% [markdown]
# You can get summary information about the dataset using the `.info()` and `.describe()` methods:

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %% [markdown]
# The key items here to look at are that there aren't any null values in the dataset, and the datatypes are all numeric (integers and floats).
#
# Next we can look at some summary statistics with the `.describe()` method:

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# min       0.012000             1.000000              6.000000     0.990070
# 25%       0.070000             7.000000             22.000000     0.995600
# 50%       0.079000            14.000000             38.000000     0.996750
# 75%       0.090000            21.000000             62.000000     0.997835
# max       0.611000            72.000000            289.000000     1.003690
#
#                 pH    sulphates      alcohol      quality
# count  1599.000000  1599.000000  1599.000000  1599.000000
# mean      3.311113     0.658149    10.422983     5.636023
# std       0.154386     0.169507     1.065668     0.807569
# min       2.740000     0.330000     8.400000     3.000000
# 25%       3.210000     0.550000     9.500000     5.000000
# 50%       3.310000     0.620000    10.200000     6.000000
# 75%       3.400000     0.730000    11.100000     6.000000
# max       4.010000     2.000000    14.900000     8.000000

# %% [markdown]
# Next, we should split up our dataframe (table) into two tables: our `X` table will have all of our features, and `y` will have the variable that we want to predict - in this case, the `quality` variable.
#
# To simplify things, we'll only use a subset of the predictors.

# %%
# Include only a few items in the feature matrix
X = df[['total sulfur dioxide', 'density', 'chlorides', 'sulphates', 'alcohol']]
y = df[['quality']]

# %% [markdown]
# We can check the `.shape` attribute to make sure that we only captured the a few columns in the `X` feature dataframe

# %%
X.shape
# Out:
# (1599, 5)

# %% [markdown]
# [Pandas is more than capable of doing correlation heatmaps](https://stackoverflow.com/questions/29432629/plot-correlation-matrix-using-pandas), using the `.style.background_gradient()` method on a correlation dataframe

# %%
corr = X.corr()
corr.style.background_gradient(cmap='viridis')
# Out:
# <style type="text/css">
# #T_c8271_row0_col0, #T_c8271_row1_col1, #T_c8271_row2_col2, #T_c8271_row3_col3, #T_c8271_row4_col4 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_c8271_row0_col1 {
#   background-color: #2c738e;
#   color: #f1f1f1;
# }
# #T_c8271_row0_col2 {
#   background-color: #3e4989;
#   color: #f1f1f1;
# }
# #T_c8271_row0_col3, #T_c8271_row1_col4, #T_c8271_row4_col0, #T_c8271_row4_col1, #T_c8271_row4_col2 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# #T_c8271_row0_col4 {
#   background-color: #424186;
#   color: #f1f1f1;
# }
# #T_c8271_row1_col0 {
#   background-color: #3e4c8a;
#   color: #f1f1f1;
# }
# #T_c8271_row1_col2 {
#   background-color: #2f6b8e;
#   color: #f1f1f1;
# }
# #T_c8271_row1_col3 {
#   background-color: #482878;
#   color: #f1f1f1;
# }
# #T_c8271_row2_col0 {
#   background-color: #404688;
#   color: #f1f1f1;
# }
# #T_c8271_row2_col1 {
#   background-color: #23888e;
#   color: #f1f1f1;
# }
# #T_c8271_row2_col3 {
#   background-color: #306a8e;
#   color: #f1f1f1;
# }
# #T_c8271_row2_col4 {
#   background-color: #423f85;
#   color: #f1f1f1;
# }
# #T_c8271_row3_col0 {
#   background-color: #404588;
#   color: #f1f1f1;
# }
# #T_c8271_row3_col1 {
#   background-color: #27808e;
#   color: #f1f1f1;
# }
# #T_c8271_row3_col2 {
#   background-color: #228d8d;
#   color: #f1f1f1;
# }
# #T_c8271_row3_col4 {
#   background-color: #2a768e;
#   color: #f1f1f1;
# }
# #T_c8271_row4_col3 {
#   background-color: #481467;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_c8271">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c8271_level0_col0" class="col_heading level0 col0" >total sulfur dioxide</th>
#       <th id="T_c8271_level0_col1" class="col_heading level0 col1" >density</th>
#       <th id="T_c8271_level0_col2" class="col_heading level0 col2" >chlorides</th>
#       <th id="T_c8271_level0_col3" class="col_heading level0 col3" >sulphates</th>
#       <th id="T_c8271_level0_col4" class="col_heading level0 col4" >alcohol</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c8271_level0_row0" class="row_heading level0 row0" >total sulfur dioxide</th>
#       <td id="T_c8271_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_c8271_row0_col1" class="data row0 col1" >0.071269</td>
#       <td id="T_c8271_row0_col2" class="data row0 col2" >0.047400</td>
#       <td id="T_c8271_row0_col3" class="data row0 col3" >0.042947</td>
#       <td id="T_c8271_row0_col4" class="data row0 col4" >-0.205654</td>
#     </tr>
#     <tr>
#       <th id="T_c8271_level0_row1" class="row_heading level0 row1" >density</th>
#       <td id="T_c8271_row1_col0" class="data row1 col0" >0.071269</td>
#       <td id="T_c8271_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_c8271_row1_col2" class="data row1 col2" >0.200632</td>
#       <td id="T_c8271_row1_col3" class="data row1 col3" >0.148506</td>
#       <td id="T_c8271_row1_col4" class="data row1 col4" >-0.496180</td>
#     </tr>
#     <tr>
#       <th id="T_c8271_level0_row2" class="row_heading level0 row2" >chlorides</th>
#       <td id="T_c8271_row2_col0" class="data row2 col0" >0.047400</td>
#       <td id="T_c8271_row2_col1" class="data row2 col1" >0.200632</td>
#       <td id="T_c8271_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_c8271_row2_col3" class="data row2 col3" >0.371260</td>
#       <td id="T_c8271_row2_col4" class="data row2 col4" >-0.221141</td>
#     </tr>
#     <tr>
#       <th id="T_c8271_level0_row3" class="row_heading level0 row3" >sulphates</th>
#       <td id="T_c8271_row3_col0" class="data row3 col0" >0.042947</td>
#       <td id="T_c8271_row3_col1" class="data row3 col1" >0.148506</td>
#       <td id="T_c8271_row3_col2" class="data row3 col2" >0.371260</td>
#       <td id="T_c8271_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_c8271_row3_col4" class="data row3 col4" >0.093595</td>
#     </tr>
#     <tr>
#       <th id="T_c8271_level0_row4" class="row_heading level0 row4" >alcohol</th>
#       <td id="T_c8271_row4_col0" class="data row4 col0" >-0.205654</td>
#       <td id="T_c8271_row4_col1" class="data row4 col1" >-0.496180</td>
#       <td id="T_c8271_row4_col2" class="data row4 col2" >-0.221141</td>
#       <td id="T_c8271_row4_col3" class="data row4 col3" >0.093595</td>
#       <td id="T_c8271_row4_col4" class="data row4 col4" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Modeling with Statsmodels

# %% [markdown]
# Here we'll use the basic ordinary least squares implementation of linear regression in `statsmodels`.

# %%
# usage: sm.OLS(response, features)
model = sm.OLS(y, X) 
results = model.fit()  # Fit the model

# print a summary of the model
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                quality   R-squared (uncentered):                   0.986
# Model:                            OLS   Adj. R-squared (uncentered):              0.986
# Method:                 Least Squares   F-statistic:                          2.218e+04
# Date:                Mon, 15 Aug 2022   Prob (F-statistic):                        0.00
# Time:                        12:00:53   Log-Likelihood:                         -1647.0
# No. Observations:                1599   AIC:                                      3304.
# Df Residuals:                    1594   BIC:                                      3331.
# Df Model:                           5
# Covariance Type:            nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# total sulfur dioxide    -0.0027      0.001     -5.021      0.000      -0.004      -0.002
# density                  1.9625      0.191     10.296      0.000       1.589       2.336
# chlorides               -2.3274      0.405     -5.753      0.000      -3.121      -1.534
# sulphates                1.2773      0.110     11.581      0.000       1.061       1.494
# alcohol                  0.3038      0.017     18.006      0.000       0.271       0.337
# ==============================================================================
# Omnibus:                       52.485   Durbin-Watson:                   1.753
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               87.016
# Skew:                          -0.277   Prob(JB):                     1.27e-19
# Kurtosis:                       3.999   Cond. No.                     1.40e+03
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [3] The condition number is large, 1.4e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# Note that it didn't fit an intercept - to add an intercept term, we would need to add in a column of ones.

# %%
# add a column of ones to X
X = X.copy()
X["intercept"] = 1

# usage: sm.OLS(response, features)
model = sm.OLS(y, X) 
results = model.fit()  # Fit the model

# print a summary of the model
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                quality   R-squared:                       0.295
# Model:                            OLS   Adj. R-squared:                  0.293
# Method:                 Least Squares   F-statistic:                     133.6
# Date:                Mon, 15 Aug 2022   Prob (F-statistic):          1.98e-118
# Time:                        12:01:04   Log-Likelihood:                -1646.6
# No. Observations:                1599   AIC:                             3305.
# Df Residuals:                    1593   BIC:                             3338.
# Df Model:                           5
# Covariance Type:            nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# total sulfur dioxide    -0.0026      0.001     -4.965      0.000      -0.004      -0.002
# density                 10.7290     10.655      1.007      0.314     -10.169      31.627
# chlorides               -2.3313      0.405     -5.762      0.000      -3.125      -1.538
# sulphates                1.2586      0.113     11.176      0.000       1.038       1.479
# alcohol                  0.3121      0.020     15.874      0.000       0.274       0.351
# intercept               -8.8130     10.709     -0.823      0.411     -29.819      12.193
# ==============================================================================
# Omnibus:                       53.527   Durbin-Watson:                   1.756
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               89.049
# Skew:                          -0.281   Prob(JB):                     4.60e-20
# Kurtosis:                       4.010   Cond. No.                     5.12e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.12e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """
